# %% [markdown]
# # Mission To Mars - Scraping and Analysis

# %%
#Import libraries
from splinter import Browser
from bs4 import BeautifulSoup
import requests
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import html5lib

# %%
#Lauch Robot
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\jimenraf\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache

# %% [markdown]
# ### Scrape Mars Weather
# https://twitter.com/marswxreport?lang=en
#
# ##### Not able to scrape twitter page with any of both methods we learned, neither with the robot nor the requests method. Below is the evidence, these methods dont bring the actual HTML code needed to pull the weather data.

# %%
#Call URL to scrape & and read HTML
url = 'https://twitter.com/marswxreport'
browser.visit(url)
html = browser.html
browser.quit()

# %%
#Parse with BeautifulSoup
soup = BeautifulSoup(html,'html.parser')

# %%
#Check contents
print(soup.prettify())
# Out:
# <html dir="ltr" lang="en" style="font-size: 15px;">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
#   <link href="//abs.twimg.com" rel="preconnect"/>
#   <link href="//api.twitter.com" rel="preconnect"/>
#   <link href="//pbs.twimg.com" rel="preconnect"/>
#   <link href="//t.co" rel="preconnect"/>
#   <link href="//video.twimg.com" rel="preconnect"/>
#   <link href="//abs.twimg.com" rel="dns-prefetch"/>
#   <link href="//api.twitter.com" rel="dns-prefetch"/>
#   <link href="//pbs.twimg.com" rel="dns-prefetch"/>
#   <link href="//t.co" rel="dns-prefetch"/>
#   <link href="//video.twimg.com" rel="dns-prefetch"/>
#   <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/client-web/polyfills.18a65025.js" nonce="" rel="preload"/>
# ...

# %%
print(soup.findAll('span'))

# %%
type(soup.findAll('span'))

# %%
for x in soup.findAll('span'):
    print(x.text)

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
print(soup.prettify())

# %%
#Since I was unable to scrape the the twitter page with nany of both methods we learned, Im setting the variable manually:
mars_weather = 'InSight sol 708 (2020-11-22) low -93.2ºC (-135.8ºF) high -8.2ºC (17.2ºF) winds from the W at 6.0 m/s (13.4 mph) gusting to 20.2 m/s (45.2 mph) pressure at 7.40 hPa'
mars_weather

# %% [markdown]
# ### Trying with selenium

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://twitter.com/marswxreport'
driver.get(url)
html = driver.page_source
driver.close()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\jimenraf\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
print(soup.prettify())
# Out:
# <html dir="ltr" lang="en" style="font-size: 15px;">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
#   <link href="//abs.twimg.com" rel="preconnect"/>
#   <link href="//api.twitter.com" rel="preconnect"/>
#   <link href="//pbs.twimg.com" rel="preconnect"/>
#   <link href="//t.co" rel="preconnect"/>
#   <link href="//video.twimg.com" rel="preconnect"/>
#   <link href="//abs.twimg.com" rel="dns-prefetch"/>
#   <link href="//api.twitter.com" rel="dns-prefetch"/>
#   <link href="//pbs.twimg.com" rel="dns-prefetch"/>
#   <link href="//t.co" rel="dns-prefetch"/>
#   <link href="//video.twimg.com" rel="dns-prefetch"/>
#   <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/client-web/polyfills.18a65025.js" nonce="" rel="preload"/>
# ...
